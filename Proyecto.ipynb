# %% [markdown]
# <a href="https://colab.research.google.com/github/seacelas/Momento3_Python/blob/main/Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sección nueva

# %%
import time
import os
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("COVID-19.xlsx")


# Funcion de la presentacion que se muestra al ejecutar el condigo
def presentacion():
    print("*************************************************************")
    texto = "   ⚡ Análisis Mortalidad de Casos COVID-19 en Colombia ⚡\n"
    for letra in texto:
        print(letra, end="", flush=True)
        time.sleep(0.05)
    print("*************************************************************")
    time.sleep(2)
    os.system("cls")

def menu():
    opcion = 0
    print("*************************************************************")
    print("                              Menu")
    print("*************************************************************")
    print("            Seleccione la opcion que desea ejecutar")
    print("")
    print("1). Grafico de barras verti. Total muertes por COVID-19 por departamento 2021")
    print("2). Grafico de barras horiz. 5 cuidades con el mayor indice de muertes 2021")
    print("3). Grafica circular. Total de casos COVID-19 2021: Confirmados / Sospechosos / Descartados")
    print("4). Grafica tipo Linea  Total de muertes por mes para el año 2020")
    print("")
    opcion = int(input())
    match opcion:
        case 1:

        case 2:

        case 3:

        case 4:

while True:
    presentacion()
    menu()
    flag = int(input("¿Quiere volver a repetir el programa?. Digite '1'para si, y '0'para no"))
    if flag == 1:
        os.system("cls")
        continue
    elif flag == 0:
        os.system("cls")
        print("Gracias por su atención")
        break
